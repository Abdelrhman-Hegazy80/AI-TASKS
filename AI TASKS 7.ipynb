# %%
class library:
    
    def __init__(self,list,name):
        self.name=name
        self.booklist=list
        self.lendDict = {}
        
        
    def displaybook(self):
         print(f"We have following books in our library: {self.name}")
        
         for book in self.booklist:    
            print (book)
            
            
    def lendbook(self,user,name):
        if book not in self.lendDict.keys():
            self.lendDict.update({book:user})
            print("book is avalivable now you can take the book")
        else:
            print({self.lendDict[book]},"book already used")
        
        
        
    def addBook(self, book):
        self.booklist.append(book)
        print("Book has been added to the book list")
        
            


    def returnBook(self, book):  
        print("Book has been return to the book list")   
        
        
        
if __name__ == '__main__':
    
    harry=library(['c++', 'paython', 'java' , 'c basics'], 'my library')
    
    while(True):
        print(f"Welcome to the {harry.name} . Enter your choose to continue")
        print("1 display books")
        print("2 lend a book ")
        print("3 add a book")
        print("4 return a book")
        
        user_choose= input()
        if user_choose  not in ['1','2','3','4']:
            print ("please enter an  avalible option")
            continue
        else:
            user_choose=int(user_choose)
            
        if user_choose==1:
            harry.displaybook()    
        
        elif user_choose== 2:
            book = input("Enter the name of the book you want to lend:")
            user = input("Enter your name")
            harry.lendbook(user, book)

        elif user_choose== 3:
            book = input("Enter the name of the book you want to add:")
            harry.addBook(book)

        elif user_choose == 4:
            book = input("Enter the name of the book you want to return:")
            harry.returnBook(book)

        else:
            print("Not an avalible option")

    
        
        print("press q to quit or c to continue")
        
        user_choose2=''
        while(user_choose2!='q' and user_choose2!='c'):
            user_choose2=input()
        if user_choose2== "q":
            exit()
            
        if user_choose2=="c":
            continue
# Out:
# Welcome to the my library . Enter your choose to continue
# 1 display books
# 2 lend a book
# 3 add a book
# 4 return a book
# 4
# Enter the name of the book you want to return:bhbh
# Book has been return to the book list
# press q to quit or c to continue
